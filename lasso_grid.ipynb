# %%
import pandas as pd
dataset= pd.read_csv("insurance_pre.csv")
dataset.head()
# Out:
#    age     sex     bmi  children smoker      charges
# 0   19  female  27.900         0    yes  16884.92400
# 1   18    male  33.770         1     no   1725.55230
# 2   28    male  33.000         3     no   4449.46200
# 3   33    male  22.705         0     no  21984.47061
# 4   32    male  28.880         0     no   3866.85520

# %%
dataset.isnull().sum()
# Out:
# age         0
# sex         0
# bmi         0
# children    0
# smoker      0
# charges     0
# dtype: int64

# %%
dataset=pd.get_dummies(dataset,drop_first=True,dtype=int)

# %%
dataset.head()
# Out:
#    age     bmi  children      charges  sex_male  smoker_yes
# 0   19  27.900         0  16884.92400         0           1
# 1   18  33.770         1   1725.55230         1           0
# 2   28  33.000         3   4449.46200         1           0
# 3   33  22.705         0  21984.47061         1           0
# 4   32  28.880         0   3866.85520         1           0

# %%
target=dataset.iloc[:,[3]]

# %%
target
# Out:
#           charges
# 0     16884.92400
# 1      1725.55230
# 2      4449.46200
# 3     21984.47061
# 4      3866.85520
# ...           ...
# 1333  10600.54830
# 1334   2205.98080
# 1335   1629.83350
# 1336   2007.94500
# 1337  29141.36030
#
# [1338 rows x 1 columns]

# %%
dataset.columns
# Out:
# Index(['age', 'bmi', 'children', 'charges', 'sex_male', 'smoker_yes'], dtype='object')

# %%
features=dataset[['age', 'bmi', 'children','sex_male', 'smoker_yes']]

# %%
features
# Out:
#       age     bmi  children  sex_male  smoker_yes
# 0      19  27.900         0         0           1
# 1      18  33.770         1         1           0
# 2      28  33.000         3         1           0
# 3      33  22.705         0         1           0
# 4      32  28.880         0         1           0
# ...   ...     ...       ...       ...         ...
# 1333   50  30.970         3         1           0
# 1334   18  31.920         0         0           0
# 1335   18  36.850         0         0           0
# 1336   21  25.800         0         0           0
# 1337   61  29.070         0         0           1
#
# [1338 rows x 5 columns]

# %%
from sklearn.linear_model import Lasso
from sklearn.model_selection import GridSearchCV
params={
    'alpha': [0.01, 0.1, 1, 10, 100],
    'max_iter': [1000, 5000, 10000]}
grid=GridSearchCV(Lasso(),params,refit=True,verbose=3,n_jobs=-1)
grid.fit(features,target)
# Out:
# Fitting 5 folds for each of 15 candidates, totalling 75 fits
# GridSearchCV(estimator=Lasso(), n_jobs=-1,
#              param_grid={'alpha': [0.01, 0.1, 1, 10, 100],
#                          'max_iter': [1000, 5000, 10000]},
#              verbose=3)

# %%
grid.best_params_
# Out:
# {'alpha': 10, 'max_iter': 1000}

# %%
re=grid.cv_results_
data=pd.DataFrame.from_dict(re)
data
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  param_alpha  \
# 0        0.007843      0.001841         0.005040        0.003263         0.01
# 1        0.005949      0.001318         0.003559        0.001508         0.01
# 2        0.007419      0.003090         0.004208        0.001957         0.01
# 3        0.006070      0.001448         0.003293        0.001128         0.10
# 4        0.005505      0.002133         0.004207        0.001555         0.10
# 5        0.005834      0.001922         0.003700        0.001122         0.10
# 6        0.003846      0.000241         0.002474        0.000216         1.00
# 7        0.004212      0.001184         0.002456        0.000410         1.00
# 8        0.003862      0.001038         0.002848        0.000548         1.00
# 9        0.006350      0.004271         0.002611        0.000397        10.00
# 10       0.003534      0.000238         0.003089        0.000559        10.00
# 11       0.003871      0.000693         0.002196        0.000236        10.00
# 12       0.003415      0.000265         0.002368        0.000320       100.00
# 13       0.003418      0.000283         0.002215        0.000187       100.00
# 14       0.003800      0.000450         0.002453        0.000172       100.00
#
#     param_max_iter                              params  split0_test_score  \
# 0             1000   {'alpha': 0.01, 'max_iter': 1000}           0.760979
# 1             5000   {'alpha': 0.01, 'max_iter': 5000}           0.760979
# 2            10000  {'alpha': 0.01, 'max_iter': 10000}           0.760979
# 3             1000    {'alpha': 0.1, 'max_iter': 1000}           0.760981
# 4             5000    {'alpha': 0.1, 'max_iter': 5000}           0.760981
# 5            10000   {'alpha': 0.1, 'max_iter': 10000}           0.760981
# 6             1000      {'alpha': 1, 'max_iter': 1000}           0.761000
# 7             5000      {'alpha': 1, 'max_iter': 5000}           0.761000
# 8            10000     {'alpha': 1, 'max_iter': 10000}           0.761000
# 9             1000     {'alpha': 10, 'max_iter': 1000}           0.761183
# 10            5000     {'alpha': 10, 'max_iter': 5000}           0.761183
# 11           10000    {'alpha': 10, 'max_iter': 10000}           0.761183
# 12            1000    {'alpha': 100, 'max_iter': 1000}           0.762172
# 13            5000    {'alpha': 100, 'max_iter': 5000}           0.762172
# 14           10000   {'alpha': 100, 'max_iter': 10000}           0.762172
#
#     split1_test_score  split2_test_score  split3_test_score  \
# 0            0.708734           0.775584           0.731367
# 1            0.708734           0.775584           0.731367
# 2            0.708734           0.775584           0.731367
# 3            0.708736           0.775583           0.731368
# 4            0.708736           0.775583           0.731368
# 5            0.708736           0.775583           0.731368
# 6            0.708758           0.775569           0.731382
# 7            0.708758           0.775569           0.731382
# 8            0.708758           0.775569           0.731382
# 9            0.708975           0.775431           0.731512
# 10           0.708975           0.775431           0.731512
# 11           0.708975           0.775431           0.731512
# 12           0.710552           0.772687           0.732342
# 13           0.710552           0.772687           0.732342
# 14           0.710552           0.772687           0.732342
#
#     split4_test_score  mean_test_score  std_test_score  rank_test_score
# 0            0.756545         0.746642        0.023713               10
# 1            0.756545         0.746642        0.023713               10
# 2            0.756545         0.746642        0.023713               10
# 3            0.756544         0.746642        0.023712                7
# 4            0.756544         0.746642        0.023712                7
# 5            0.756544         0.746642        0.023712                7
# 6            0.756537         0.746649        0.023702                4
# 7            0.756537         0.746649        0.023702                4
# 8            0.756537         0.746649        0.023702                4
# 9            0.756463         0.746713        0.023598                1
# 10           0.756463         0.746713        0.023598                1
# 11           0.756463         0.746713        0.023598                1
# 12           0.754922         0.746535        0.022338               13
# 13           0.754922         0.746535        0.022338               13
# 14           0.754922         0.746535        0.022338               13

# %%
y_pred=grid.predict(features)

# %%
from sklearn.metrics import r2_score
r_score = r2_score(y_pred,target)

# %%
r_score
# Out:
# 0.6646411754017174
